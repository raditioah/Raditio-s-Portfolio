# %% [markdown]
# # Membuat data kelas dengan tipe data dictionary

# %%
import pandas as pd

# %%
data = {'NPM': [184220001,184220002,184220003,184220004,184220005,184220007,184220008,184220010,184220011,184220012,
               184220013,184220015,184220019,184220021,184220022,184220023,184220024,184220025,184220026,184220027,
               184220028,184220029,184220030,184220031,184220032,184220033],
    
       'Nama': [' Mhd. Haikal Baihaqi',' Gilang Al-Raffi','Siti Salwa Azzahra','Maria Bernadina B. Cintany Lustin',
                 'Muhamad Rafif Al-Hafizh','Paulina Bota Kolin','L.M.Aznur Syahfajar','Mylo Aleffa Rahman',
                 'Sabrina Nur Anisah','Muhammad Vito Aristawidya','Firna Ulfiani R','Muhammad Reefy Hidayatullah',
                 'Aulia Rahmadiva Wardana','Maysa Zaidee Aulia','NAUFAL PANJI PURNOMO','Salsa Paringga Pangestu Ningsih',
                 'Nita Sawalia Fitri','Christopher Damar Nugroho Amizeno Ranga Sogen','Fahriza Aulia Rahman','Ridla Ashrina',
                 'Gabriella Mustika Anugraheni','Thiodas Heni Pakpahan','Aldi Daim Fauzan','NASYWA NUR HANDAYANI',
                 'Yusuf','Raditio Ananto Hargiyanto']}

df = pd.DataFrame(data)

# %%
df
# Out:
#           NPM                                           Nama
# 0   184220001                            Mhd. Haikal Baihaqi
# 1   184220002                                Gilang Al-Raffi
# 2   184220003                             Siti Salwa Azzahra
# 3   184220004              Maria Bernadina B. Cintany Lustin
# 4   184220005                        Muhamad Rafif Al-Hafizh
# 5   184220007                             Paulina Bota Kolin
# 6   184220008                            L.M.Aznur Syahfajar
# 7   184220010                             Mylo Aleffa Rahman
# 8   184220011                             Sabrina Nur Anisah
# 9   184220012                      Muhammad Vito Aristawidya
# 10  184220013                                Firna Ulfiani R
# 11  184220015                    Muhammad Reefy Hidayatullah
# 12  184220019                        Aulia Rahmadiva Wardana
# 13  184220021                             Maysa Zaidee Aulia
# ...

# %% [markdown]
# # Upload file csv

# %%
# df = data frame
df = pd.read_csv("Data Kelas Sains Data.csv")

# %%
df
# Out:
#           NPM                                           NAMA
# 0   184220001                            Mhd. Haikal Baihaqi
# 1   184220002                                Gilang Al-Raffi
# 2   184220003                             Siti Salwa Azzahra
# 3   184220004              Maria Bernadina B. Cintany Lustin
# 4   184220005                        Muhamad Rafif Al-Hafizh
# 5   184220007                             Paulina Bota Kolin
# 6   184220008                            L.M.Aznur Syahfajar
# 7   184220010                             Mylo Aleffa Rahman
# 8   184220011                             Sabrina Nur Anisah
# 9   184220012                      Muhammad Vito Aristawidya
# 10  184220013                                Firna Ulfiani R
# 11  184220015                    Muhammad Reefy Hidayatullah
# 12  184220019                        Aulia Rahmadiva Wardana
# 13  184220021                             Maysa Zaidee Aulia
# ...

# %% [markdown]
# # Menambah data label

# %%
df['DOMISILI'] = ['Sumatra Utara', 'Jawa Barat', 'Jawa Barat','NTT','Jawa Barat','NTT',
                 'Sulawesi Tenggara','Jawa Barat','Jawa Timur','Sumatra Barat','Jawa Timur',
                 'Jawa Barat','Kalimantan Tengah','Bali','Jawa Tengah','Jawa Tengah','Jawa Barat',
                 'Jawa Tengah','Jawa Barat','Jawa Barat','Jawa Barat','Sumatra Utara','Jawa Barat','Jawa Barat','Jawa Barat',
                 'Jawa Barat']

# %% [markdown]
# Penambahan dengan cara diatas akan menambah data pada akhir label

# %%
df
# Out:
#           NPM                                           NAMA  \
# 0   184220001                            Mhd. Haikal Baihaqi
# 1   184220002                                Gilang Al-Raffi
# 2   184220003                             Siti Salwa Azzahra
# 3   184220004              Maria Bernadina B. Cintany Lustin
# 4   184220005                        Muhamad Rafif Al-Hafizh
# 5   184220007                             Paulina Bota Kolin
# 6   184220008                            L.M.Aznur Syahfajar
# 7   184220010                             Mylo Aleffa Rahman
# 8   184220011                             Sabrina Nur Anisah
# 9   184220012                      Muhammad Vito Aristawidya
# 10  184220013                                Firna Ulfiani R
# 11  184220015                    Muhammad Reefy Hidayatullah
# 12  184220019                        Aulia Rahmadiva Wardana
# 13  184220021                             Maysa Zaidee Aulia
# ...

# %% [markdown]
# Penambahan data dibawah ini akan menambah data sesuai yang kita inginkan sesuai index
# *Bisa diantara dua data yang sudah ada*

# %% [markdown]
# Dibawah ini label GENDER ditambahkan diantara NAMA dan DOMISILI

# %%
df.insert(2, 'GENDER', ['Pria','Pria','Wanita','Wanita','Pria','Wanita','Pria','Pria',
                       'Wanita','Pria','Wanita','Pria','Wanita','Wanita','Pria','Wanita',
                       'Wanita','Pria','Pria','Wanita','Wanita','Wanita','Pria','Wanita','Pria','Pria'])

# %%
df
# Out:
#           NPM                                           NAMA  GENDER  \
# 0   184220001                            Mhd. Haikal Baihaqi    Pria
# 1   184220002                                Gilang Al-Raffi    Pria
# 2   184220003                             Siti Salwa Azzahra  Wanita
# 3   184220004              Maria Bernadina B. Cintany Lustin  Wanita
# 4   184220005                        Muhamad Rafif Al-Hafizh    Pria
# 5   184220007                             Paulina Bota Kolin  Wanita
# 6   184220008                            L.M.Aznur Syahfajar    Pria
# 7   184220010                             Mylo Aleffa Rahman    Pria
# 8   184220011                             Sabrina Nur Anisah  Wanita
# 9   184220012                      Muhammad Vito Aristawidya    Pria
# 10  184220013                                Firna Ulfiani R  Wanita
# 11  184220015                    Muhammad Reefy Hidayatullah    Pria
# 12  184220019                        Aulia Rahmadiva Wardana  Wanita
# ...

# %% [markdown]
# Dibawah ini penambahan label UMUR diantara NAMA dan GENDER

# %%
df.insert(2, 'UMUR', [20,19,18,19,19,22,19,20,
                       19,19,22,19,19,19,20,19,
                       20,19,19,19,19,20,20,19,19,20])

# %%
df
# Out:
#           NPM                                           NAMA  UMUR  GENDER  \
# 0   184220001                            Mhd. Haikal Baihaqi    20    Pria
# 1   184220002                                Gilang Al-Raffi    19    Pria
# 2   184220003                             Siti Salwa Azzahra    18  Wanita
# 3   184220004              Maria Bernadina B. Cintany Lustin    19  Wanita
# 4   184220005                        Muhamad Rafif Al-Hafizh    19    Pria
# 5   184220007                             Paulina Bota Kolin    22  Wanita
# 6   184220008                            L.M.Aznur Syahfajar    19    Pria
# 7   184220010                             Mylo Aleffa Rahman    20    Pria
# 8   184220011                             Sabrina Nur Anisah    19  Wanita
# 9   184220012                      Muhammad Vito Aristawidya    19    Pria
# 10  184220013                                Firna Ulfiani R    22  Wanita
# ...

# %% [markdown]
# # Menganalisis data

# %%
df['UMUR'].value_counts()
# Out:
# 19    16
# 20     7
# 22     2
# 18     1
# Name: UMUR, dtype: int64

# %%
df['GENDER'].value_counts()
# Out:
# Pria      13
# Wanita    13
# Name: GENDER, dtype: int64

# %%
df['DOMISILI'].value_counts()
# Out:
# Jawa Barat           13
# Jawa Tengah           3
# Sumatra Utara         2
# NTT                   2
# Jawa Timur            2
# Sulawesi Tenggara     1
# Sumatra Barat         1
# Kalimantan Tengah     1
# Bali                  1
# Name: DOMISILI, dtype: int64

# %% [markdown]
# # Menghapus data tertentu

# %% [markdown]
# Pada contoh dibawah saya menghapus data label NPM

# %%
df1 = df.drop(['NPM'],axis='columns')
df1
# Out:
#                                              NAMA  UMUR  GENDER  \
# 0                             Mhd. Haikal Baihaqi    20    Pria
# 1                                 Gilang Al-Raffi    19    Pria
# 2                              Siti Salwa Azzahra    18  Wanita
# 3               Maria Bernadina B. Cintany Lustin    19  Wanita
# 4                         Muhamad Rafif Al-Hafizh    19    Pria
# 5                              Paulina Bota Kolin    22  Wanita
# 6                             L.M.Aznur Syahfajar    19    Pria
# 7                              Mylo Aleffa Rahman    20    Pria
# 8                              Sabrina Nur Anisah    19  Wanita
# 9                       Muhammad Vito Aristawidya    19    Pria
# 10                                Firna Ulfiani R    22  Wanita
# 11                    Muhammad Reefy Hidayatullah    19    Pria
# 12                        Aulia Rahmadiva Wardana    19  Wanita
# 13                             Maysa Zaidee Aulia    19  Wanita
# ...
